# %%
import pandas as pd
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
os.getcwd()
# Out:
# 'C:\\Users\\MAHIREDDY\\OneDrive\\Desktop\\ssn-internship(facial recognition)'

# %%
dataset=pd.read_csv(r'C:\\Users\\MAHIREDDY\\OneDrive\\Desktop\\ssn-internship(facial recognition)\\LFW\\train.csv')

# %%
dataset.head()
# Out:
#                     Image1                          Image2      class  \
# 0  Elizabeth_Dole_0001.jpg         Elizabeth_Dole_0003.jpg    similar
# 1    Shia_LaBeouf_0001.jpg      Tatyana_Tomashova_0001.jpg  different
# 2   Earl_Campbell_0001.jpg  Marco_Antonio_Barrera_0003.jpg  different
# 3      Diana_Munz_0003.jpg          Geno_Auriemma_0001.jpg  different
# 4     Freda_Black_0001.jpg      Patricia_Clarkson_0003.jpg  different
#
#   face_present
# 0          Yes
# 1          Yes
# 2          Yes
# 3          Yes
# 4           No

# %%
image=cv2.imread('C:\\Users\\MAHIREDDY\\OneDrive\\Desktop\\ssn-internship(facial recognition)\\LFW\\Faces\\Aaron_Sorkin_0001.jpg')

# %%
img=Image.open('C:\\Users\\MAHIREDDY\\OneDrive\\Desktop\\ssn-internship(facial recognition)\\LFW\\Faces\\Aaron_Sorkin_0001.jpg')

# %%
plt.imshow(img)
