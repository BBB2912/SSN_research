# %%
# !pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/87/ac/fe69868ff03b9488504398018841edf9cd07bb77ce47aa32b1d13a8b52a5/ultralytics-8.2.22-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/40.7 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.7 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.7 kB ? eta -:--:--
#      ---------------------------- --------- 30.7/40.7 kB 217.9 kB/s eta 0:00:01
#      -------------------------------------- 40.7/40.7 kB 243.6 kB/s eta 0:00:00
# ...
#   Obtaining dependency information for torch>=1.8.0 from https://files.pythonhosted.org/packages/2a/b7/a3cf5fd40334b9785cc83ee0c96b50603026eb3aa70210a33729018e7029/torch-2.3.0-cp311-cp311-win_amd64.whl.metadata
# ...

# %%
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ultralytics import YOLO
#
# ModuleNotFoundError: No module named 'ultralytics'
